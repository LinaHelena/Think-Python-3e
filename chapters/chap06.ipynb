# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve

        local, _ = urlretrieve(url, filename)
        print("Downloaded " + str(local))
    return filename

download('https://github.com/AllenDowney/ThinkPython/raw/v3/thinkpython.py');
download('https://github.com/AllenDowney/ThinkPython/raw/v3/diagram.py');

import thinkpython
# Out:
# Downloaded thinkpython.py
# Downloaded diagram.py

# %% [markdown]
# # Return Values
#
# In previous chapters, we've used built-in functions -- like `abs` and `round` -- and functions in the math module -- like `sqrt` and `pow`.
# When you call one of these functions, it returns a value you can assign to a variable or use as part of an expression.
#
# The functions we have written so far are different.
# Some use the `print` function to display values, and some use turtle functions to draw figures.
# But they don't return values we assign to variables or use in expressions.
#
# In this chapter, we'll see how to write functions that return values.

# %% [markdown]
# ## Some functions have return values
#
# When you call a function like `math.sqrt`, the result is called a **return value**.
# If the function call appears at the end of a cell, Jupyter displays the return value immediately.

# %%
import math

math.sqrt(42 / math.pi)
# Out:
# 3.656366395715726

# %% [markdown]
# If you assign the return value to a variable, it doesn't get displayed.

# %%
radius = math.sqrt(42 / math.pi)

# %% [markdown]
# But you can display it later.

# %%
radius
# Out:
# 3.656366395715726

# %% [markdown]
# Or you can use the return value as part of an expression.

# %%
radius + math.sqrt(42 / math.pi)
# Out:
# 7.312732791431452

# %% [markdown]
# Here's an example of a function that returns a value.

# %%
def circle_area(radius):
    area = math.pi * radius**2
    return area

# %% [markdown]
# `circle_area` takes `radius` as a parameter and computes the area of a circle with that radius.
#
# The last line is a `return` statement that returns the value of `area`.
#
# If we call the function like this, Jupyter displays the return value.

# %%
circle_area(radius)
# Out:
# 42.00000000000001

# %% [markdown]
# We can assign the return value to a variable.

# %%
a = circle_area(radius)

# %% [markdown]
# Or use it as part of an expression.

# %%
circle_area(radius) + 2 * circle_area(radius / 2)
# Out:
# 63.000000000000014

# %% [markdown]
# Later we can display the value of the variable we assigned the result to.

# %%
a
# Out:
# 42.00000000000001

# %% [markdown]
# But we can't access `area`.

# %%
# %%expect NameError
#
# area
# Out:
# NameError: name 'area' is not defined

# %% [markdown]
# `area` is a local variable in a function, so we can't access it from outside the function.

# %% [markdown]
# ## And some have None
#
# If a function doesn't have a `return` statement, it returns `None`, which is a special value like `True` and `False`.
# For example, here's the `repeat` function from Chapter 3.

# %%
def repeat(word, n):
    print(word * n)

# %% [markdown]
# If we call it like this, it displays the first line of the Monty Python song "Finland".

# %%
repeat('Finland, ', 3)
# Out:
# Finland, Finland, Finland,

# %% [markdown]
# This function uses the `print` function to display a string, but it does not use a `return` statement to return a value.
# If we assign the result to a variable, it displays the string anyway.

# %%
result = repeat('Finland, ', 3)
# Out:
# Finland, Finland, Finland,

# %% [markdown]
# And if we display the value of the variable, we get nothing.

# %%
result

# %% [markdown]
# `result` actually has a value, but Jupyter doesn't show it.
# However, we can display it like this.

# %%
print(result)
# Out:
# None

# %% [markdown]
# The return value from `repeat` is `None`.
#
# Now here's a function similar to `repeat` except that has a return value.

# %%
def repeat_string(word, n):
    return word * n

# %% [markdown]
# Notice that we can use an expression in a `return` statement, not just a variable.
#
# With this version, we can assign the result to a variable.
# When the function runs, it doesn't display anything.

# %%
line = repeat_string('Spam, ', 4)

# %% [markdown]
# But later we can display the value assigned to `line`.

# %%
line
# Out:
# 'Spam, Spam, Spam, Spam, '

# %% [markdown]
# A function like this is called a **pure function** because it doesn't display anything or have any other effect -- other than returning a value.

# %% [markdown]
# ## Return values and conditionals
#
# If Python did not provide `abs`, we could write it like this.

# %%
def absolute_value(x):
    if x < 0:
        return -x
    else:
        return x

# %% [markdown]
# If `x` is negative, the first `return` statement returns `-x` and the function ends immediately.
# Otherwise, the second `return` statement returns `x` and the function ends.
# So this function is correct.
#
# However, if you put `return` statements in a conditional, you have to make sure that every possible path through the program hits a `return` statement.
# For example, here's an incorrect version of `absolute_value`.

# %%
def absolute_value_wrong(x):
    if x < 0:
        return -x
    if x > 0:
        return x

# %% [markdown]
# Here's what happens if we call this function with `0` as an argument.

# %%
absolute_value_wrong(0)

# %% [markdown]
# We get nothing! Here's the problem: when `x` is `0`, neither condition is true, and the function ends without hitting a `return` statement, which means that the return value is `None`, so Jupyter displays nothing.
#
# As another example, here's a version of `absolute_value` with an extra `return` statement at the end.

# %%
def absolute_value_extra_return(x):
    if x < 0:
        return -x
    else:
        return x

    return 'This is dead code'

# %% [markdown]
# If `x` is negative, the first `return` statement runs and the function ends.
# Otherwise the second `return` statement runs and the function ends.
# Either way, we never get to the third `return` statement -- so it can never run.
#
# Code that can never run is called **dead code**.
# In general, dead code doesn't do any harm, but it often indicates a misunderstanding, and it might be confusing to someone trying to understand the program.

# %% [markdown]
# ## Incremental development
#
# As you write larger functions, you might find yourself spending more
# time debugging.
# To deal with increasingly complex programs, you might want to try **incremental development**, which is a way of adding and testing only a small amount of code at a time.
#
# As an example, suppose you want to find the distance between two points represented by the coordinates $(x_1, y_1)$ and $(x_2, y_2)$.
# By the Pythagorean theorem, the distance is:
#
# $$\mathrm{distance} = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$$
#
# The first step is to consider what a `distance` function should look like in Python -- that is, what are the inputs (parameters) and what is the output (return value)?
#
# For this function, the inputs are the coordinates of the points.
# The return value is the distance.
# Immediately you can write an outline of the function:

# %%
def distance(x1, y1, x2, y2):
    return 0.0

# %% [markdown]
# This version doesn't compute distances yet -- it always returns zero.
# But it is a complete function with a return value, which means that you can test it before you make it more complicated.
#
# To test the new function, we'll call it with sample arguments:

# %%
distance(1, 2, 4, 6)
# Out:
# 0.0

# %% [markdown]
# I chose these values so that the horizontal distance is `3` and the
# vertical distance is `4`.
# That way, the result is `5`, the hypotenuse of a `3-4-5` right triangle. When testing a function, it is useful to know the right answer.
#
# At this point we have confirmed that the function runs and returns a value, and we can start adding code to the body.
# A good next step is to find the differences `x2 - x1` and `y2 - y1`.
# Here's a version that stores those values in temporary variables and displays them.

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    print('dx is', dx)
    print('dy is', dy)
    return 0.0

# %% [markdown]
# If the function is working, it should display `dx is 3` and `dy is 4`.
# If so, we know that the function is getting the right arguments and
# performing the first computation correctly. If not, there are only a few
# lines to check.

# %%
distance(1, 2, 4, 6)
# Out:
# dx is 3
# dy is 4
# 0.0

# %% [markdown]
# Good so far. Next we compute the sum of squares of `dx` and `dy`:

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    print('dsquared is: ', dsquared)
    return 0.0

# %% [markdown]
# Again, we can run the function and check the output, which should be `25`.

# %%
distance(1, 2, 4, 6)

# %% [markdown]
# Finally, we can use `math.sqrt` to compute the distance:

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = math.sqrt(dsquared)
    print("result is", result)

# %% [markdown]
# And test it.

# %%
distance(1, 2, 4, 6)
# Out:
# result is 5.0

# %% [markdown]
# The result is correct, but this version of the function displays the result rather than returning it, so the return value is `None`.
#
# We can fix that by replacing the `print` function with a `return` statement.

# %%
def distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    dsquared = dx**2 + dy**2
    result = math.sqrt(dsquared)
    return result

# %% [markdown]
# This version of `distance` is a pure function.
# If we call it like this, only the result is displayed.

# %%
distance(1, 2, 4, 6)
# Out:
# 5.0

# %% [markdown]
# And if we assign the result to a variable, nothing is displayed.

# %%
d = distance(1, 2, 4, 6)

# %% [markdown]
# The `print` statements we wrote are useful for debugging, but once the function is working, we can remove them.
# Code like that is called **scaffolding** because it is helpful for building the program but is not part of the final product.
#
# This example demonstrates incremental development.
# The key aspects of this process are:
#
# 1.  Start with a working program, make small changes, and test after every change.
#
# 2.  Use variables to hold intermediate values so you can display and check them.
#
# 3.  Once the program is working, remove the scaffolding.
#
# At any point, if there is an error, you should have a good idea where it is.
# Incremental development can save you a lot of debugging time.

# %% [markdown]
# ## Boolean functions
#
# Functions can return the boolean values `True` and `False`, which is often convenient for encapsulating a complex test in a function.
# For example, `is_divisible` checks whether `x` is divisible by `y` with no remainder.

# %%
def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False

# %% [markdown]
# Here's how we use it.

# %%
is_divisible(6, 4)
# Out:
# False

# %%
is_divisible(6, 3)
# Out:
# True

# %% [markdown]
# Inside the function, the result of the `==` operator is a boolean, so we can write the
# function more concisely by returning it directly.

# %%
def is_divisible(x, y):
    return x % y == 0

# %% [markdown]
# Boolean functions are often used in conditional statements.

# %%
if is_divisible(6, 2):
    print('divisible')
# Out:
# divisible

# %% [markdown]
# It might be tempting to write something like this:

# %%
if is_divisible(6, 2) == True:
    print('divisible')
# Out:
# divisible

# %% [markdown]
# But the comparison is unnecessary.

# %% [markdown]
# ## Recursion with return values
#
# Now that we can write functions with return values, we can write recursive functions with return values, and with that capability, we have passed an important threshold -- the subset of Python we have is now **Turing complete**, which means that we can perform any computation that can be described by an algorithm.
#
# To demonstrate recursion with return values, we'll evaluate a few recursively defined mathematical functions.
# A recursive definition is similar to a circular definition, in the sense that the definition refers to the thing being defined. A truly circular definition is not very useful:
#
# > vorpal: An adjective used to describe something that is vorpal.
#
# If you saw that definition in the dictionary, you might be annoyed.
# On the other hand, if you looked up the definition of the factorial function, denoted with the symbol $!$, you might get something like this:
#
# $$\begin{aligned}
# 0! &= 1 \\
# n! &= n~(n-1)!
# \end{aligned}$$
#
# This definition says that the factorial of $0$ is $1$, and the factorial of any other value, $n$, is $n$ multiplied by the factorial of $n-1$.
#
# If you can write a recursive definition of something, you can write a Python program to evaluate it.
# Following an incremental development process, we'll start with a function that take `n` as a parameter and always returns `0`.

# %%
def factorial(n):
    return 0

# %% [markdown]
# Now let's add the first part of the definition -- if the argument happens to be `0`, all we have to do is return `1`:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return 0

# %% [markdown]
# Now let's fill in the second part -- if `n` is not `0`, we have to make a recursive
# call to find the factorial of `n-1` and then multiply the result by `n`:

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        recurse = factorial(n-1)
        return n * recurse

# %% [markdown]
# The flow of execution for this program is similar to the flow of `countdown` in Chapter 5.
# If we call `factorial` with the value `3`:
#
# Since `3` is not `0`, we take the second branch and calculate the factorial
# of `n-1`\...
#
# > Since `2` is not `0`, we take the second branch and calculate the
# > factorial of `n-1`\...
# >
# > > Since `1` is not `0`, we take the second branch and calculate the
# > > factorial of `n-1`\...
# > >
# > > > Since `0` equals `0`, we take the first branch and return `1` without
# > > > making any more recursive calls.
# > >
# > > The return value, `1`, is multiplied by `n`, which is `1`, and the
# > > result is returned.
# >
# > The return value, `1`, is multiplied by `n`, which is `2`, and the result
# > is returned.
#
# The return value `2` is multiplied by `n`, which is `3`, and the result,
# `6`, becomes the return value of the function call that started the whole
# process.
#
# The following figure shows the stack diagram for this sequence of function calls.

# %%
from diagram import Frame, Stack, make_binding

main = Frame([], name='__main__', loc='left')
frames = [main]

ns = 3, 2, 1
recurses = 2, 1, 1
results = 6, 2, 1

for n, recurse, result in zip(ns, recurses, results):
    binding1 = make_binding('n', n)
    binding2 = make_binding('recurse', recurse)
    frame = Frame([binding1, binding2],
                  name='factorial', value=result,
                  loc='left', dx=1.2)
    frames.append(frame)

binding1 = make_binding('n', 0)
frame = Frame([binding1], name='factorial', value=1,
              shim=1.2, loc='left', dx=1.4)
frames.append(frame)

stack = Stack(frames, dy=-0.45)

# %%
from diagram import diagram, adjust

width, height, x, y = [2.74, 2.26, 0.73, 2.05]
ax = diagram(width, height)
bbox = stack.draw(ax, x, y)
# adjust(x, y, bbox)

# %% [markdown]
# The return values are shown being passed back up the stack.
# In each frame, the return value is the product of `n` and `recurse`.
#
# In the last frame, the local variable `recurse` does not exist because the branch that creates it does not run.

# %% [markdown]
# ## Leap of faith
#
# Following the flow of execution is one way to read programs, but it can quickly become overwhelming. An alternative is what I call the "leap of faith". When you come to a function call, instead of following the flow of execution, you *assume* that the function works correctly and returns the right result.
#
# In fact, you are already practicing this leap of faith when you use built-in functions.
# When you call `abs` or `math.sqrt`, you don't examine the bodies of those functions -- you just assume that they work.
#
# The same is true when you call one of your own functions. For example, earlier we wrote a function called `is_divisible` that determines whether one number is divisible by another. Once we convince ourselves that this function is correct, we can use it without looking at the body again.
#
# The same is true of recursive programs.
# When you get to the recursive call, instead of following the flow of execution, you should assume that the recursive call works and then ask yourself, "Assuming that I can compute the factorial of $n-1$, can I compute the factorial of $n$?"
# The recursive definition of factorial implies that you can, by multiplying by $n$.
#
# Of course, it's a bit strange to assume that the function works correctly when you haven't finished writing it, but that's why it's called a leap of faith!

# %% [markdown]
# ## Fibonacci
#
# After `factorial`, the most common example of a recursive function is `fibonacci`, which has the following definition:
#
# $$\begin{aligned}
# \mathrm{fibonacci}(0) &= 0 \\
# \mathrm{fibonacci}(1) &= 1 \\
# \mathrm{fibonacci}(n) &= \mathrm{fibonacci}(n-1) + \mathrm{fibonacci}(n-2)
# \end{aligned}$$
#
# Translated into Python, it looks like this:

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif  n == 1:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)

# %% [markdown]
# If you try to follow the flow of execution here, even for small values of $n$, your head explodes.
# But according to the leap of faith, if you assume that the two recursive calls work correctly, you can be confident that the last `return` statement is correct.
#
# As an aside, this way of computing Fibonacci numbers is very inefficient.
# In [Chapter 10](section_memos) I'll explain why and suggest a way to improve it.

# %% [markdown]
# ## Checking types
#
# What happens if we call `factorial` and give it `1.5` as an argument?

# %%
# %%expect RecursionError
#
# factorial(1.5)
# Out:
# 0

# %% [markdown]
# It looks like an infinite recursion. How can that be? The function has base cases when `n == 1` or `n == 0`.
# But if `n` is not an integer, we can *miss* the base case and recurse forever.
#
# In this example, the initial value of `n` is `1.5`.
# In the first recursive call, the value of `n` is `0.5`.
# In the next, it is `-0.5`.
# From there, it gets smaller (more negative), but it will never be `0`.
#
# To avoid infinite recursion we can use the built-in function `isinstance` to check the type of the argument.
# Here's how we check whether a value is an integer.

# %%
isinstance(3, int)
# Out:
# True

# %%
isinstance(1.5, int)
# Out:
# False

# %% [markdown]
# Now here's a version of `factorial` with error-checking.

# %%
def factorial(n):
    if not isinstance(n, int):
        print('factorial is only defined for integers.')
        return None
    elif n < 0:
        print('factorial is not defined for negative numbers.')
        return None
    elif n == 0:
        return 1
    else:
        return n * factorial(n-1)

# %% [markdown]
# First it checks whether `n` is an integer.
# If not, it displays an error message and returns `None`.

# %%
factorial('crunchy frog')
# Out:
# factorial is only defined for integers.

# %% [markdown]
# Then it checks whether `n` is negative.
# If so, it displays an error message and returns `None.`

# %%
factorial(-2)
# Out:
# factorial is not defined for negative numbers.

# %% [markdown]
# If we get past both checks, we know that `n` is a non-negative integer, so we can be confident the recursion will terminate.
# Checking the parameters of a function to make sure they have the correct types and values is called **input validation**.

# %% [markdown]
# ## Debugging
#
# Breaking a large program into smaller functions creates natural checkpoints for debugging.
# If a function is not working, there are three possibilities to consider:
#
# -   There is something wrong with the arguments the function is getting -- that is, a precondition is violated.
#
# -   There is something wrong with the function -- that is, a postcondition is violated.
#
# -   The caller is doing something wrong with the return value.
#
# To rule out the first possibility, you can add a `print` statement at the beginning of the function that displays the values of the parameters (and maybe their types).
# Or you can write code that checks the preconditions explicitly.
#
# If the parameters look good, you can add a `print` statement before each `return` statement and display the return value.
# If possible, call the function with arguments that make it easy check the result.
#
# If the function seems to be working, look at the function call to make sure the return value is being used correctly -- or used at all!
#
# Adding `print` statements at the beginning and end of a function can help make the flow of execution more visible.
# For example, here is a version of `factorial` with print statements:

# %%
def factorial(n):
    space = ' ' * (4 * n)
    print(space, 'factorial', n)
    if n == 0:
        print(space, 'returning 1')
        return 1
    else:
        recurse = factorial(n-1)
        result = n * recurse
        print(space, 'returning', result)
        return result

# %% [markdown]
# `space` is a string of space characters that controls the indentation of
# the output. Here is the result of `factorial(3)` :

# %%
factorial(3)
# Out:
#              factorial 3
#          factorial 2
#      factorial 1
#  factorial 0
#  returning 1
#      returning 1
#          returning 2
#              returning 6
# 6

# %% [markdown]
# If you are confused about the flow of execution, this kind of output can be helpful.
# It takes some time to develop effective scaffolding, but a little bit of scaffolding can save a lot of debugging.

# %% [markdown]
# ## Glossary
#
# **return value:**
# The result of a function. If a function call is used as an expression, the return value is the value of the expression.
#
# **pure function:**
# A function that does not display anything or have any other effect, other than returning a return value.
#
#
# **dead code:**
# Part of a program that can never run, often because it appears after a `return` statement.
#
# **incremental development:**
# A program development plan intended to avoid debugging by adding and testing only a small amount of code at a time.
#
# **scaffolding:**
#  Code that is used during program development but is not part of the final version.
#
# **Turing complete:**
# A language, or subset of a language, is Turing complete if it can perform any computation that can be described by an algorithm.
#
# **input validation:**
# Checking the parameters of a function to make sure they have the correct types and values

# %% [markdown]
# ## Exercises

# %%
# This cell tells Jupyter to provide detailed debugging information
# when a runtime error occurs. Run it before working on the exercises.

# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %% [markdown]
# ### Ask a virtual assistant
#
# In this chapter, we saw an incorrect function that can end without returning a value.

# %%
def absolute_value_wrong(x):
    if x < 0:
        return -x
    if x > 0:
        return x

# %%
#Corected version, the problem with the first one was the lack of return if 0.
def absolute_value(x):
    if x < 0:
        return -x
    elif x > 0:
        return x
    else:
        return 0

# %% [markdown]
# And a version of the same function that has dead code at the end.

# %%
def absolute_value_extra_return(x):
    if x < 0:
        return -x
    else:
        return x

    return 'This is dead code.'

# %%
#Improved code, the above code is an example of dead code, Python will never execute that last line.

def absolute_value(x):
    if x < 0:
        return -x
    return x

# %% [markdown]
# And we saw the following example, which is correct but not idiomatic.

# %%
def is_divisible(x, y):
    if x % y == 0:
        return True
    else:
        return False

# %%
#The above code is redundant, we do not need both true and false.
def is_divisible(x, y):
    return x % y == 0

# %% [markdown]
# Ask a virtual assistant what's wrong with each of these functions and see if it can spot the errors or improve the style.
#
# Then ask "Write a function that takes coordinates of two points and computes the distance between them." See if the result resembles the version of `distance` we wrote in this chapter.

# %%
def distance(x1, y1, x2, y2):
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

print(distance(0, 0, 3, 4))  # → 5.0  (classic 3-4-5 triangle)
print(distance(1, 2, 4, 6))  # → 5.0
# Out:
# 5.0
# 5.0

# %% [markdown]
# ### Exercise
#
# Use incremental development to write a function called `hypot` that returns the length of the hypotenuse of a right triangle given the lengths of the other two legs as arguments.
#
# Note: There's a function in the math module called `hypot` that does the same thing, but you should not use it for this exercise!
#
# Even if you can write the function correctly on the first try, start with a function that always returns `0` and practice making small changes, testing as you go.
# When you are done, the function should only return a value -- it should not display anything.

# %%
def hypot(a, b):
    return 0

# %%
def hypot(a, b):
    return a**2 + b**2

# %%
print(hypot(3, 4))  # → 25 (3^2 + 4^2)
# Out:
# 25

# %%
print(hypot(3, 4))  # → 25 (3^2 + 4^2)
# Out:
# 25

# %%
import math

def hypot(a, b):
    return math.sqrt(a**2 + b**2)

# %%
print(hypot(3, 4))  # → 5.0
print(hypot(5, 12)) # → 13.0
# Out:
# 5.0
# 13.0

# %%
# or
def hypot(a, b):
    sum_squares = a**2 + b**2   # Step 1: calculate a² + b²
    hypotenuse = sum_squares**0.5  # Step 2: take the square root
    return hypotenuse

# %%
# Solution goes here

# %%
# Solution goes here

# %%
# Solution goes here

# %% [markdown]
# ### Exercise
#
# Write a boolean function, `is_between(x, y, z)`, that returns `True` if $x < y < z$ or if
# $z < y < x$, and`False` otherwise.

# %%
def is_between(x, y, z):
    return (x < y < z) or (z < y < x)

# %% [markdown]
# You can use these examples to test your function.

# %%
is_between(1, 2, 3)  # should be True
# Out:
# True

# %%
is_between(3, 2, 1)  # should be True
# Out:
# True

# %%
is_between(1, 3, 2)  # should be False
# Out:
# False

# %%
is_between(2, 3, 1)  # should be False
# Out:
# False

# %% [markdown]
# ### Exercise
#
# The Ackermann function, $A(m, n)$, is defined:
#
# $$\begin{aligned}
# A(m, n) = \begin{cases}
#               n+1 & \mbox{if } m = 0 \\
#         A(m-1, 1) & \mbox{if } m > 0 \mbox{ and } n = 0 \\
# A(m-1, A(m, n-1)) & \mbox{if } m > 0 \mbox{ and } n > 0.
# \end{cases}
# \end{aligned}$$
#
# Write a function named `ackermann` that evaluates the Ackermann function.
# What happens if you call `ackermann(5, 5)`?

# %%
def ackermann(m, n):
    print("ackermann called with m =", m, "n =", n)  # <-- print statement added
    if m == 0:
        return n + 1
    elif n == 0:
        return ackermann(m-1, 1)
    else:
        return ackermann(m-1, ackermann(m, n-1))

# %% [markdown]
# You can use these examples to test your function.

# %%
ackermann(3, 2)  # should be 29
# Out:
# ackermann called with m = 3 n = 2
# ackermann called with m = 3 n = 1
# ackermann called with m = 3 n = 0
# ackermann called with m = 2 n = 1
# ackermann called with m = 2 n = 0
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 2 n = 5
# ackermann called with m = 2 n = 4
# ackermann called with m = 2 n = 3
# ackermann called with m = 2 n = 2
# ackermann called with m = 2 n = 1
# ackermann called with m = 2 n = 0
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 2 n = 13
# ackermann called with m = 2 n = 12
# ackermann called with m = 2 n = 11
# ackermann called with m = 2 n = 10
# ackermann called with m = 2 n = 9
# ackermann called with m = 2 n = 8
# ackermann called with m = 2 n = 7
# ackermann called with m = 2 n = 6
# ackermann called with m = 2 n = 5
# ackermann called with m = 2 n = 4
# ackermann called with m = 2 n = 3
# ackermann called with m = 2 n = 2
# ackermann called with m = 2 n = 1
# ackermann called with m = 2 n = 0
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 1 n = 21
# ackermann called with m = 1 n = 20
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 0 n = 21
# ackermann called with m = 0 n = 22
# ackermann called with m = 1 n = 23
# ackermann called with m = 1 n = 22
# ackermann called with m = 1 n = 21
# ackermann called with m = 1 n = 20
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 0 n = 21
# ackermann called with m = 0 n = 22
# ackermann called with m = 0 n = 23
# ackermann called with m = 0 n = 24
# ackermann called with m = 1 n = 25
# ackermann called with m = 1 n = 24
# ackermann called with m = 1 n = 23
# ackermann called with m = 1 n = 22
# ackermann called with m = 1 n = 21
# ackermann called with m = 1 n = 20
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 0 n = 21
# ackermann called with m = 0 n = 22
# ackermann called with m = 0 n = 23
# ackermann called with m = 0 n = 24
# ackermann called with m = 0 n = 25
# ackermann called with m = 0 n = 26
# ackermann called with m = 1 n = 27
# ackermann called with m = 1 n = 26
# ackermann called with m = 1 n = 25
# ackermann called with m = 1 n = 24
# ackermann called with m = 1 n = 23
# ackermann called with m = 1 n = 22
# ackermann called with m = 1 n = 21
# ackermann called with m = 1 n = 20
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 0 n = 21
# ackermann called with m = 0 n = 22
# ackermann called with m = 0 n = 23
# ackermann called with m = 0 n = 24
# ackermann called with m = 0 n = 25
# ackermann called with m = 0 n = 26
# ackermann called with m = 0 n = 27
# ackermann called with m = 0 n = 28
# 29

# %%
ackermann(3, 3)  # should be 61
# Out:
# 61

# %%
ackermann(3, 4)  # should be 125
# Out:
# 125

# %% [markdown]
# If you call this function with values bigger than 4, you get a `RecursionError`.

# %%
# %%expect RecursionError
#
# ackermann(5, 5)
# Out:
# Utdata för streaming har trunkerats till de sista 5000 raderna.
# ackermann called with m = 1 n = 640
# ackermann called with m = 1 n = 639
# ackermann called with m = 1 n = 638
# ackermann called with m = 1 n = 637
# ackermann called with m = 1 n = 636
# ackermann called with m = 1 n = 635
# ackermann called with m = 1 n = 634
# ackermann called with m = 1 n = 633
# ackermann called with m = 1 n = 632
# ackermann called with m = 1 n = 631
# ackermann called with m = 1 n = 630
# ackermann called with m = 1 n = 629
# ackermann called with m = 1 n = 628
# ackermann called with m = 1 n = 627
# ackermann called with m = 1 n = 626
# ackermann called with m = 1 n = 625
# ackermann called with m = 1 n = 624
# ackermann called with m = 1 n = 623
# ackermann called with m = 1 n = 622
# ackermann called with m = 1 n = 621
# ackermann called with m = 1 n = 620
# ackermann called with m = 1 n = 619
# ackermann called with m = 1 n = 618
# ackermann called with m = 1 n = 617
# ackermann called with m = 1 n = 616
# ackermann called with m = 1 n = 615
# ackermann called with m = 1 n = 614
# ackermann called with m = 1 n = 613
# ackermann called with m = 1 n = 612
# ackermann called with m = 1 n = 611
# ackermann called with m = 1 n = 610
# ackermann called with m = 1 n = 609
# ackermann called with m = 1 n = 608
# ackermann called with m = 1 n = 607
# ackermann called with m = 1 n = 606
# ackermann called with m = 1 n = 605
# ackermann called with m = 1 n = 604
# ackermann called with m = 1 n = 603
# ackermann called with m = 1 n = 602
# ackermann called with m = 1 n = 601
# ackermann called with m = 1 n = 600
# ackermann called with m = 1 n = 599
# ackermann called with m = 1 n = 598
# ackermann called with m = 1 n = 597
# ackermann called with m = 1 n = 596
# ackermann called with m = 1 n = 595
# ackermann called with m = 1 n = 594
# ackermann called with m = 1 n = 593
# ackermann called with m = 1 n = 592
# ackermann called with m = 1 n = 591
# ackermann called with m = 1 n = 590
# ackermann called with m = 1 n = 589
# ackermann called with m = 1 n = 588
# ackermann called with m = 1 n = 587
# ackermann called with m = 1 n = 586
# ackermann called with m = 1 n = 585
# ackermann called with m = 1 n = 584
# ackermann called with m = 1 n = 583
# ackermann called with m = 1 n = 582
# ackermann called with m = 1 n = 581
# ackermann called with m = 1 n = 580
# ackermann called with m = 1 n = 579
# ackermann called with m = 1 n = 578
# ackermann called with m = 1 n = 577
# ackermann called with m = 1 n = 576
# ackermann called with m = 1 n = 575
# ackermann called with m = 1 n = 574
# ackermann called with m = 1 n = 573
# ackermann called with m = 1 n = 572
# ackermann called with m = 1 n = 571
# ackermann called with m = 1 n = 570
# ackermann called with m = 1 n = 569
# ackermann called with m = 1 n = 568
# ackermann called with m = 1 n = 567
# ackermann called with m = 1 n = 566
# ackermann called with m = 1 n = 565
# ackermann called with m = 1 n = 564
# ackermann called with m = 1 n = 563
# ackermann called with m = 1 n = 562
# ackermann called with m = 1 n = 561
# ackermann called with m = 1 n = 560
# ackermann called with m = 1 n = 559
# ackermann called with m = 1 n = 558
# ackermann called with m = 1 n = 557
# ackermann called with m = 1 n = 556
# ackermann called with m = 1 n = 555
# ackermann called with m = 1 n = 554
# ackermann called with m = 1 n = 553
# ackermann called with m = 1 n = 552
# ackermann called with m = 1 n = 551
# ackermann called with m = 1 n = 550
# ackermann called with m = 1 n = 549
# ackermann called with m = 1 n = 548
# ackermann called with m = 1 n = 547
# ackermann called with m = 1 n = 546
# ackermann called with m = 1 n = 545
# ackermann called with m = 1 n = 544
# ackermann called with m = 1 n = 543
# ackermann called with m = 1 n = 542
# ackermann called with m = 1 n = 541
# ackermann called with m = 1 n = 540
# ackermann called with m = 1 n = 539
# ackermann called with m = 1 n = 538
# ackermann called with m = 1 n = 537
# ackermann called with m = 1 n = 536
# ackermann called with m = 1 n = 535
# ackermann called with m = 1 n = 534
# ackermann called with m = 1 n = 533
# ackermann called with m = 1 n = 532
# ackermann called with m = 1 n = 531
# ackermann called with m = 1 n = 530
# ackermann called with m = 1 n = 529
# ackermann called with m = 1 n = 528
# ackermann called with m = 1 n = 527
# ackermann called with m = 1 n = 526
# ackermann called with m = 1 n = 525
# ackermann called with m = 1 n = 524
# ackermann called with m = 1 n = 523
# ackermann called with m = 1 n = 522
# ackermann called with m = 1 n = 521
# ackermann called with m = 1 n = 520
# ackermann called with m = 1 n = 519
# ackermann called with m = 1 n = 518
# ackermann called with m = 1 n = 517
# ackermann called with m = 1 n = 516
# ackermann called with m = 1 n = 515
# ackermann called with m = 1 n = 514
# ackermann called with m = 1 n = 513
# ackermann called with m = 1 n = 512
# ackermann called with m = 1 n = 511
# ackermann called with m = 1 n = 510
# ackermann called with m = 1 n = 509
# ackermann called with m = 1 n = 508
# ackermann called with m = 1 n = 507
# ackermann called with m = 1 n = 506
# ackermann called with m = 1 n = 505
# ackermann called with m = 1 n = 504
# ackermann called with m = 1 n = 503
# ackermann called with m = 1 n = 502
# ackermann called with m = 1 n = 501
# ackermann called with m = 1 n = 500
# ackermann called with m = 1 n = 499
# ackermann called with m = 1 n = 498
# ackermann called with m = 1 n = 497
# ackermann called with m = 1 n = 496
# ackermann called with m = 1 n = 495
# ackermann called with m = 1 n = 494
# ackermann called with m = 1 n = 493
# ackermann called with m = 1 n = 492
# ackermann called with m = 1 n = 491
# ackermann called with m = 1 n = 490
# ackermann called with m = 1 n = 489
# ackermann called with m = 1 n = 488
# ackermann called with m = 1 n = 487
# ackermann called with m = 1 n = 486
# ackermann called with m = 1 n = 485
# ackermann called with m = 1 n = 484
# ackermann called with m = 1 n = 483
# ackermann called with m = 1 n = 482
# ackermann called with m = 1 n = 481
# ackermann called with m = 1 n = 480
# ackermann called with m = 1 n = 479
# ackermann called with m = 1 n = 478
# ackermann called with m = 1 n = 477
# ackermann called with m = 1 n = 476
# ackermann called with m = 1 n = 475
# ackermann called with m = 1 n = 474
# ackermann called with m = 1 n = 473
# ackermann called with m = 1 n = 472
# ackermann called with m = 1 n = 471
# ackermann called with m = 1 n = 470
# ackermann called with m = 1 n = 469
# ackermann called with m = 1 n = 468
# ackermann called with m = 1 n = 467
# ackermann called with m = 1 n = 466
# ackermann called with m = 1 n = 465
# ackermann called with m = 1 n = 464
# ackermann called with m = 1 n = 463
# ackermann called with m = 1 n = 462
# ackermann called with m = 1 n = 461
# ackermann called with m = 1 n = 460
# ackermann called with m = 1 n = 459
# ackermann called with m = 1 n = 458
# ackermann called with m = 1 n = 457
# ackermann called with m = 1 n = 456
# ackermann called with m = 1 n = 455
# ackermann called with m = 1 n = 454
# ackermann called with m = 1 n = 453
# ackermann called with m = 1 n = 452
# ackermann called with m = 1 n = 451
# ackermann called with m = 1 n = 450
# ackermann called with m = 1 n = 449
# ackermann called with m = 1 n = 448
# ackermann called with m = 1 n = 447
# ackermann called with m = 1 n = 446
# ackermann called with m = 1 n = 445
# ackermann called with m = 1 n = 444
# ackermann called with m = 1 n = 443
# ackermann called with m = 1 n = 442
# ackermann called with m = 1 n = 441
# ackermann called with m = 1 n = 440
# ackermann called with m = 1 n = 439
# ackermann called with m = 1 n = 438
# ackermann called with m = 1 n = 437
# ackermann called with m = 1 n = 436
# ackermann called with m = 1 n = 435
# ackermann called with m = 1 n = 434
# ackermann called with m = 1 n = 433
# ackermann called with m = 1 n = 432
# ackermann called with m = 1 n = 431
# ackermann called with m = 1 n = 430
# ackermann called with m = 1 n = 429
# ackermann called with m = 1 n = 428
# ackermann called with m = 1 n = 427
# ackermann called with m = 1 n = 426
# ackermann called with m = 1 n = 425
# ackermann called with m = 1 n = 424
# ackermann called with m = 1 n = 423
# ackermann called with m = 1 n = 422
# ackermann called with m = 1 n = 421
# ackermann called with m = 1 n = 420
# ackermann called with m = 1 n = 419
# ackermann called with m = 1 n = 418
# ackermann called with m = 1 n = 417
# ackermann called with m = 1 n = 416
# ackermann called with m = 1 n = 415
# ackermann called with m = 1 n = 414
# ackermann called with m = 1 n = 413
# ackermann called with m = 1 n = 412
# ackermann called with m = 1 n = 411
# ackermann called with m = 1 n = 410
# ackermann called with m = 1 n = 409
# ackermann called with m = 1 n = 408
# ackermann called with m = 1 n = 407
# ackermann called with m = 1 n = 406
# ackermann called with m = 1 n = 405
# ackermann called with m = 1 n = 404
# ackermann called with m = 1 n = 403
# ackermann called with m = 1 n = 402
# ackermann called with m = 1 n = 401
# ackermann called with m = 1 n = 400
# ackermann called with m = 1 n = 399
# ackermann called with m = 1 n = 398
# ackermann called with m = 1 n = 397
# ackermann called with m = 1 n = 396
# ackermann called with m = 1 n = 395
# ackermann called with m = 1 n = 394
# ackermann called with m = 1 n = 393
# ackermann called with m = 1 n = 392
# ackermann called with m = 1 n = 391
# ackermann called with m = 1 n = 390
# ackermann called with m = 1 n = 389
# ackermann called with m = 1 n = 388
# ackermann called with m = 1 n = 387
# ackermann called with m = 1 n = 386
# ackermann called with m = 1 n = 385
# ackermann called with m = 1 n = 384
# ackermann called with m = 1 n = 383
# ackermann called with m = 1 n = 382
# ackermann called with m = 1 n = 381
# ackermann called with m = 1 n = 380
# ackermann called with m = 1 n = 379
# ackermann called with m = 1 n = 378
# ackermann called with m = 1 n = 377
# ackermann called with m = 1 n = 376
# ackermann called with m = 1 n = 375
# ackermann called with m = 1 n = 374
# ackermann called with m = 1 n = 373
# ackermann called with m = 1 n = 372
# ackermann called with m = 1 n = 371
# ackermann called with m = 1 n = 370
# ackermann called with m = 1 n = 369
# ackermann called with m = 1 n = 368
# ackermann called with m = 1 n = 367
# ackermann called with m = 1 n = 366
# ackermann called with m = 1 n = 365
# ackermann called with m = 1 n = 364
# ackermann called with m = 1 n = 363
# ackermann called with m = 1 n = 362
# ackermann called with m = 1 n = 361
# ackermann called with m = 1 n = 360
# ackermann called with m = 1 n = 359
# ackermann called with m = 1 n = 358
# ackermann called with m = 1 n = 357
# ackermann called with m = 1 n = 356
# ackermann called with m = 1 n = 355
# ackermann called with m = 1 n = 354
# ackermann called with m = 1 n = 353
# ackermann called with m = 1 n = 352
# ackermann called with m = 1 n = 351
# ackermann called with m = 1 n = 350
# ackermann called with m = 1 n = 349
# ackermann called with m = 1 n = 348
# ackermann called with m = 1 n = 347
# ackermann called with m = 1 n = 346
# ackermann called with m = 1 n = 345
# ackermann called with m = 1 n = 344
# ackermann called with m = 1 n = 343
# ackermann called with m = 1 n = 342
# ackermann called with m = 1 n = 341
# ackermann called with m = 1 n = 340
# ackermann called with m = 1 n = 339
# ackermann called with m = 1 n = 338
# ackermann called with m = 1 n = 337
# ackermann called with m = 1 n = 336
# ackermann called with m = 1 n = 335
# ackermann called with m = 1 n = 334
# ackermann called with m = 1 n = 333
# ackermann called with m = 1 n = 332
# ackermann called with m = 1 n = 331
# ackermann called with m = 1 n = 330
# ackermann called with m = 1 n = 329
# ackermann called with m = 1 n = 328
# ackermann called with m = 1 n = 327
# ackermann called with m = 1 n = 326
# ackermann called with m = 1 n = 325
# ackermann called with m = 1 n = 324
# ackermann called with m = 1 n = 323
# ackermann called with m = 1 n = 322
# ackermann called with m = 1 n = 321
# ackermann called with m = 1 n = 320
# ackermann called with m = 1 n = 319
# ackermann called with m = 1 n = 318
# ackermann called with m = 1 n = 317
# ackermann called with m = 1 n = 316
# ackermann called with m = 1 n = 315
# ackermann called with m = 1 n = 314
# ackermann called with m = 1 n = 313
# ackermann called with m = 1 n = 312
# ackermann called with m = 1 n = 311
# ackermann called with m = 1 n = 310
# ackermann called with m = 1 n = 309
# ackermann called with m = 1 n = 308
# ackermann called with m = 1 n = 307
# ackermann called with m = 1 n = 306
# ackermann called with m = 1 n = 305
# ackermann called with m = 1 n = 304
# ackermann called with m = 1 n = 303
# ackermann called with m = 1 n = 302
# ackermann called with m = 1 n = 301
# ackermann called with m = 1 n = 300
# ackermann called with m = 1 n = 299
# ackermann called with m = 1 n = 298
# ackermann called with m = 1 n = 297
# ackermann called with m = 1 n = 296
# ackermann called with m = 1 n = 295
# ackermann called with m = 1 n = 294
# ackermann called with m = 1 n = 293
# ackermann called with m = 1 n = 292
# ackermann called with m = 1 n = 291
# ackermann called with m = 1 n = 290
# ackermann called with m = 1 n = 289
# ackermann called with m = 1 n = 288
# ackermann called with m = 1 n = 287
# ackermann called with m = 1 n = 286
# ackermann called with m = 1 n = 285
# ackermann called with m = 1 n = 284
# ackermann called with m = 1 n = 283
# ackermann called with m = 1 n = 282
# ackermann called with m = 1 n = 281
# ackermann called with m = 1 n = 280
# ackermann called with m = 1 n = 279
# ackermann called with m = 1 n = 278
# ackermann called with m = 1 n = 277
# ackermann called with m = 1 n = 276
# ackermann called with m = 1 n = 275
# ackermann called with m = 1 n = 274
# ackermann called with m = 1 n = 273
# ackermann called with m = 1 n = 272
# ackermann called with m = 1 n = 271
# ackermann called with m = 1 n = 270
# ackermann called with m = 1 n = 269
# ackermann called with m = 1 n = 268
# ackermann called with m = 1 n = 267
# ackermann called with m = 1 n = 266
# ackermann called with m = 1 n = 265
# ackermann called with m = 1 n = 264
# ackermann called with m = 1 n = 263
# ackermann called with m = 1 n = 262
# ackermann called with m = 1 n = 261
# ackermann called with m = 1 n = 260
# ackermann called with m = 1 n = 259
# ackermann called with m = 1 n = 258
# ackermann called with m = 1 n = 257
# ackermann called with m = 1 n = 256
# ackermann called with m = 1 n = 255
# ackermann called with m = 1 n = 254
# ackermann called with m = 1 n = 253
# ackermann called with m = 1 n = 252
# ackermann called with m = 1 n = 251
# ackermann called with m = 1 n = 250
# ackermann called with m = 1 n = 249
# ackermann called with m = 1 n = 248
# ackermann called with m = 1 n = 247
# ackermann called with m = 1 n = 246
# ackermann called with m = 1 n = 245
# ackermann called with m = 1 n = 244
# ackermann called with m = 1 n = 243
# ackermann called with m = 1 n = 242
# ackermann called with m = 1 n = 241
# ackermann called with m = 1 n = 240
# ackermann called with m = 1 n = 239
# ackermann called with m = 1 n = 238
# ackermann called with m = 1 n = 237
# ackermann called with m = 1 n = 236
# ackermann called with m = 1 n = 235
# ackermann called with m = 1 n = 234
# ackermann called with m = 1 n = 233
# ackermann called with m = 1 n = 232
# ackermann called with m = 1 n = 231
# ackermann called with m = 1 n = 230
# ackermann called with m = 1 n = 229
# ackermann called with m = 1 n = 228
# ackermann called with m = 1 n = 227
# ackermann called with m = 1 n = 226
# ackermann called with m = 1 n = 225
# ackermann called with m = 1 n = 224
# ackermann called with m = 1 n = 223
# ackermann called with m = 1 n = 222
# ackermann called with m = 1 n = 221
# ackermann called with m = 1 n = 220
# ackermann called with m = 1 n = 219
# ackermann called with m = 1 n = 218
# ackermann called with m = 1 n = 217
# ackermann called with m = 1 n = 216
# ackermann called with m = 1 n = 215
# ackermann called with m = 1 n = 214
# ackermann called with m = 1 n = 213
# ackermann called with m = 1 n = 212
# ackermann called with m = 1 n = 211
# ackermann called with m = 1 n = 210
# ackermann called with m = 1 n = 209
# ackermann called with m = 1 n = 208
# ackermann called with m = 1 n = 207
# ackermann called with m = 1 n = 206
# ackermann called with m = 1 n = 205
# ackermann called with m = 1 n = 204
# ackermann called with m = 1 n = 203
# ackermann called with m = 1 n = 202
# ackermann called with m = 1 n = 201
# ackermann called with m = 1 n = 200
# ackermann called with m = 1 n = 199
# ackermann called with m = 1 n = 198
# ackermann called with m = 1 n = 197
# ackermann called with m = 1 n = 196
# ackermann called with m = 1 n = 195
# ackermann called with m = 1 n = 194
# ackermann called with m = 1 n = 193
# ackermann called with m = 1 n = 192
# ackermann called with m = 1 n = 191
# ackermann called with m = 1 n = 190
# ackermann called with m = 1 n = 189
# ackermann called with m = 1 n = 188
# ackermann called with m = 1 n = 187
# ackermann called with m = 1 n = 186
# ackermann called with m = 1 n = 185
# ackermann called with m = 1 n = 184
# ackermann called with m = 1 n = 183
# ackermann called with m = 1 n = 182
# ackermann called with m = 1 n = 181
# ackermann called with m = 1 n = 180
# ackermann called with m = 1 n = 179
# ackermann called with m = 1 n = 178
# ackermann called with m = 1 n = 177
# ackermann called with m = 1 n = 176
# ackermann called with m = 1 n = 175
# ackermann called with m = 1 n = 174
# ackermann called with m = 1 n = 173
# ackermann called with m = 1 n = 172
# ackermann called with m = 1 n = 171
# ackermann called with m = 1 n = 170
# ackermann called with m = 1 n = 169
# ackermann called with m = 1 n = 168
# ackermann called with m = 1 n = 167
# ackermann called with m = 1 n = 166
# ackermann called with m = 1 n = 165
# ackermann called with m = 1 n = 164
# ackermann called with m = 1 n = 163
# ackermann called with m = 1 n = 162
# ackermann called with m = 1 n = 161
# ackermann called with m = 1 n = 160
# ackermann called with m = 1 n = 159
# ackermann called with m = 1 n = 158
# ackermann called with m = 1 n = 157
# ackermann called with m = 1 n = 156
# ackermann called with m = 1 n = 155
# ackermann called with m = 1 n = 154
# ackermann called with m = 1 n = 153
# ackermann called with m = 1 n = 152
# ackermann called with m = 1 n = 151
# ackermann called with m = 1 n = 150
# ackermann called with m = 1 n = 149
# ackermann called with m = 1 n = 148
# ackermann called with m = 1 n = 147
# ackermann called with m = 1 n = 146
# ackermann called with m = 1 n = 145
# ackermann called with m = 1 n = 144
# ackermann called with m = 1 n = 143
# ackermann called with m = 1 n = 142
# ackermann called with m = 1 n = 141
# ackermann called with m = 1 n = 140
# ackermann called with m = 1 n = 139
# ackermann called with m = 1 n = 138
# ackermann called with m = 1 n = 137
# ackermann called with m = 1 n = 136
# ackermann called with m = 1 n = 135
# ackermann called with m = 1 n = 134
# ackermann called with m = 1 n = 133
# ackermann called with m = 1 n = 132
# ackermann called with m = 1 n = 131
# ackermann called with m = 1 n = 130
# ackermann called with m = 1 n = 129
# ackermann called with m = 1 n = 128
# ackermann called with m = 1 n = 127
# ackermann called with m = 1 n = 126
# ackermann called with m = 1 n = 125
# ackermann called with m = 1 n = 124
# ackermann called with m = 1 n = 123
# ackermann called with m = 1 n = 122
# ackermann called with m = 1 n = 121
# ackermann called with m = 1 n = 120
# ackermann called with m = 1 n = 119
# ackermann called with m = 1 n = 118
# ackermann called with m = 1 n = 117
# ackermann called with m = 1 n = 116
# ackermann called with m = 1 n = 115
# ackermann called with m = 1 n = 114
# ackermann called with m = 1 n = 113
# ackermann called with m = 1 n = 112
# ackermann called with m = 1 n = 111
# ackermann called with m = 1 n = 110
# ackermann called with m = 1 n = 109
# ackermann called with m = 1 n = 108
# ackermann called with m = 1 n = 107
# ackermann called with m = 1 n = 106
# ackermann called with m = 1 n = 105
# ackermann called with m = 1 n = 104
# ackermann called with m = 1 n = 103
# ackermann called with m = 1 n = 102
# ackermann called with m = 1 n = 101
# ackermann called with m = 1 n = 100
# ackermann called with m = 1 n = 99
# ackermann called with m = 1 n = 98
# ackermann called with m = 1 n = 97
# ackermann called with m = 1 n = 96
# ackermann called with m = 1 n = 95
# ackermann called with m = 1 n = 94
# ackermann called with m = 1 n = 93
# ackermann called with m = 1 n = 92
# ackermann called with m = 1 n = 91
# ackermann called with m = 1 n = 90
# ackermann called with m = 1 n = 89
# ackermann called with m = 1 n = 88
# ackermann called with m = 1 n = 87
# ackermann called with m = 1 n = 86
# ackermann called with m = 1 n = 85
# ackermann called with m = 1 n = 84
# ackermann called with m = 1 n = 83
# ackermann called with m = 1 n = 82
# ackermann called with m = 1 n = 81
# ackermann called with m = 1 n = 80
# ackermann called with m = 1 n = 79
# ackermann called with m = 1 n = 78
# ackermann called with m = 1 n = 77
# ackermann called with m = 1 n = 76
# ackermann called with m = 1 n = 75
# ackermann called with m = 1 n = 74
# ackermann called with m = 1 n = 73
# ackermann called with m = 1 n = 72
# ackermann called with m = 1 n = 71
# ackermann called with m = 1 n = 70
# ackermann called with m = 1 n = 69
# ackermann called with m = 1 n = 68
# ackermann called with m = 1 n = 67
# ackermann called with m = 1 n = 66
# ackermann called with m = 1 n = 65
# ackermann called with m = 1 n = 64
# ackermann called with m = 1 n = 63
# ackermann called with m = 1 n = 62
# ackermann called with m = 1 n = 61
# ackermann called with m = 1 n = 60
# ackermann called with m = 1 n = 59
# ackermann called with m = 1 n = 58
# ackermann called with m = 1 n = 57
# ackermann called with m = 1 n = 56
# ackermann called with m = 1 n = 55
# ackermann called with m = 1 n = 54
# ackermann called with m = 1 n = 53
# ackermann called with m = 1 n = 52
# ackermann called with m = 1 n = 51
# ackermann called with m = 1 n = 50
# ackermann called with m = 1 n = 49
# ackermann called with m = 1 n = 48
# ackermann called with m = 1 n = 47
# ackermann called with m = 1 n = 46
# ackermann called with m = 1 n = 45
# ackermann called with m = 1 n = 44
# ackermann called with m = 1 n = 43
# ackermann called with m = 1 n = 42
# ackermann called with m = 1 n = 41
# ackermann called with m = 1 n = 40
# ackermann called with m = 1 n = 39
# ackermann called with m = 1 n = 38
# ackermann called with m = 1 n = 37
# ackermann called with m = 1 n = 36
# ackermann called with m = 1 n = 35
# ackermann called with m = 1 n = 34
# ackermann called with m = 1 n = 33
# ackermann called with m = 1 n = 32
# ackermann called with m = 1 n = 31
# ackermann called with m = 1 n = 30
# ackermann called with m = 1 n = 29
# ackermann called with m = 1 n = 28
# ackermann called with m = 1 n = 27
# ackermann called with m = 1 n = 26
# ackermann called with m = 1 n = 25
# ackermann called with m = 1 n = 24
# ackermann called with m = 1 n = 23
# ackermann called with m = 1 n = 22
# ackermann called with m = 1 n = 21
# ackermann called with m = 1 n = 20
# ackermann called with m = 1 n = 19
# ackermann called with m = 1 n = 18
# ackermann called with m = 1 n = 17
# ackermann called with m = 1 n = 16
# ackermann called with m = 1 n = 15
# ackermann called with m = 1 n = 14
# ackermann called with m = 1 n = 13
# ackermann called with m = 1 n = 12
# ackermann called with m = 1 n = 11
# ackermann called with m = 1 n = 10
# ackermann called with m = 1 n = 9
# ackermann called with m = 1 n = 8
# ackermann called with m = 1 n = 7
# ackermann called with m = 1 n = 6
# ackermann called with m = 1 n = 5
# ackermann called with m = 1 n = 4
# ackermann called with m = 1 n = 3
# ackermann called with m = 1 n = 2
# ackermann called with m = 1 n = 1
# ackermann called with m = 1 n = 0
# ackermann called with m = 0 n = 1
# ackermann called with m = 0 n = 2
# ackermann called with m = 0 n = 3
# ackermann called with m = 0 n = 4
# ackermann called with m = 0 n = 5
# ackermann called with m = 0 n = 6
# ackermann called with m = 0 n = 7
# ackermann called with m = 0 n = 8
# ackermann called with m = 0 n = 9
# ackermann called with m = 0 n = 10
# ackermann called with m = 0 n = 11
# ackermann called with m = 0 n = 12
# ackermann called with m = 0 n = 13
# ackermann called with m = 0 n = 14
# ackermann called with m = 0 n = 15
# ackermann called with m = 0 n = 16
# ackermann called with m = 0 n = 17
# ackermann called with m = 0 n = 18
# ackermann called with m = 0 n = 19
# ackermann called with m = 0 n = 20
# ackermann called with m = 0 n = 21
# ackermann called with m = 0 n = 22
# ackermann called with m = 0 n = 23
# ackermann called with m = 0 n = 24
# ackermann called with m = 0 n = 25
# ackermann called with m = 0 n = 26
# ackermann called with m = 0 n = 27
# ackermann called with m = 0 n = 28
# ackermann called with m = 0 n = 29
# ackermann called with m = 0 n = 30
# ackermann called with m = 0 n = 31
# ackermann called with m = 0 n = 32
# ackermann called with m = 0 n = 33
# ackermann called with m = 0 n = 34
# ackermann called with m = 0 n = 35
# ackermann called with m = 0 n = 36
# ackermann called with m = 0 n = 37
# ackermann called with m = 0 n = 38
# ackermann called with m = 0 n = 39
# ackermann called with m = 0 n = 40
# ackermann called with m = 0 n = 41
# ackermann called with m = 0 n = 42
# ackermann called with m = 0 n = 43
# ackermann called with m = 0 n = 44
# ackermann called with m = 0 n = 45
# ackermann called with m = 0 n = 46
# ackermann called with m = 0 n = 47
# ackermann called with m = 0 n = 48
# ackermann called with m = 0 n = 49
# ackermann called with m = 0 n = 50
# ackermann called with m = 0 n = 51
# ackermann called with m = 0 n = 52
# ackermann called with m = 0 n = 53
# ackermann called with m = 0 n = 54
# ackermann called with m = 0 n = 55
# ackermann called with m = 0 n = 56
# ackermann called with m = 0 n = 57
# ackermann called with m = 0 n = 58
# ackermann called with m = 0 n = 59
# ackermann called with m = 0 n = 60
# ackermann called with m = 0 n = 61
# ackermann called with m = 0 n = 62
# ackermann called with m = 0 n = 63
# ackermann called with m = 0 n = 64
# ackermann called with m = 0 n = 65
# ackermann called with m = 0 n = 66
# ackermann called with m = 0 n = 67
# ackermann called with m = 0 n = 68
# ackermann called with m = 0 n = 69
# ackermann called with m = 0 n = 70
# ackermann called with m = 0 n = 71
# ackermann called with m = 0 n = 72
# ackermann called with m = 0 n = 73
# ackermann called with m = 0 n = 74
# ackermann called with m = 0 n = 75
# ackermann called with m = 0 n = 76
# ackermann called with m = 0 n = 77
# ackermann called with m = 0 n = 78
# ackermann called with m = 0 n = 79
# ackermann called with m = 0 n = 80
# ackermann called with m = 0 n = 81
# ackermann called with m = 0 n = 82
# ackermann called with m = 0 n = 83
# ackermann called with m = 0 n = 84
# ackermann called with m = 0 n = 85
# ackermann called with m = 0 n = 86
# ackermann called with m = 0 n = 87
# ackermann called with m = 0 n = 88
# ackermann called with m = 0 n = 89
# ackermann called with m = 0 n = 90
# ackermann called with m = 0 n = 91
# ackermann called with m = 0 n = 92
# ackermann called with m = 0 n = 93
# ackermann called with m = 0 n = 94
# ackermann called with m = 0 n = 95
# ackermann called with m = 0 n = 96
# ackermann called with m = 0 n = 97
# ackermann called with m = 0 n = 98
# ackermann called with m = 0 n = 99
# ackermann called with m = 0 n = 100
# ackermann called with m = 0 n = 101
# ackermann called with m = 0 n = 102
# ackermann called with m = 0 n = 103
# ackermann called with m = 0 n = 104
# ackermann called with m = 0 n = 105
# ackermann called with m = 0 n = 106
# ackermann called with m = 0 n = 107
# ackermann called with m = 0 n = 108
# ackermann called with m = 0 n = 109
# ackermann called with m = 0 n = 110
# ackermann called with m = 0 n = 111
# ackermann called with m = 0 n = 112
# ackermann called with m = 0 n = 113
# ackermann called with m = 0 n = 114
# ackermann called with m = 0 n = 115
# ackermann called with m = 0 n = 116
# ackermann called with m = 0 n = 117
# ackermann called with m = 0 n = 118
# ackermann called with m = 0 n = 119
# ackermann called with m = 0 n = 120
# ackermann called with m = 0 n = 121
# ackermann called with m = 0 n = 122
# ackermann called with m = 0 n = 123
# ackermann called with m = 0 n = 124
# ackermann called with m = 0 n = 125
# ackermann called with m = 0 n = 126
# ackermann called with m = 0 n = 127
# ackermann called with m = 0 n = 128
# ackermann called with m = 0 n = 129
# ackermann called with m = 0 n = 130
# ackermann called with m = 0 n = 131
# ackermann called with m = 0 n = 132
# ackermann called with m = 0 n = 133
# ackermann called with m = 0 n = 134
# ackermann called with m = 0 n = 135
# ackermann called with m = 0 n = 136
# ackermann called with m = 0 n = 137
# ackermann called with m = 0 n = 138
# ackermann called with m = 0 n = 139
# ackermann called with m = 0 n = 140
# ackermann called with m = 0 n = 141
# ackermann called with m = 0 n = 142
# ackermann called with m = 0 n = 143
# ackermann called with m = 0 n = 144
# ackermann called with m = 0 n = 145
# ackermann called with m = 0 n = 146
# ackermann called with m = 0 n = 147
# ackermann called with m = 0 n = 148
# ackermann called with m = 0 n = 149
# ackermann called with m = 0 n = 150
# ackermann called with m = 0 n = 151
# ackermann called with m = 0 n = 152
# ackermann called with m = 0 n = 153
# ackermann called with m = 0 n = 154
# ackermann called with m = 0 n = 155
# ackermann called with m = 0 n = 156
# ackermann called with m = 0 n = 157
# ackermann called with m = 0 n = 158
# ackermann called with m = 0 n = 159
# ackermann called with m = 0 n = 160
# ackermann called with m = 0 n = 161
# ackermann called with m = 0 n = 162
# ackermann called with m = 0 n = 163
# ackermann called with m = 0 n = 164
# ackermann called with m = 0 n = 165
# ackermann called with m = 0 n = 166
# ackermann called with m = 0 n = 167
# ackermann called with m = 0 n = 168
# ackermann called with m = 0 n = 169
# ackermann called with m = 0 n = 170
# ackermann called with m = 0 n = 171
# ackermann called with m = 0 n = 172
# ackermann called with m = 0 n = 173
# ackermann called with m = 0 n = 174
# ackermann called with m = 0 n = 175
# ackermann called with m = 0 n = 176
# ackermann called with m = 0 n = 177
# ackermann called with m = 0 n = 178
# ackermann called with m = 0 n = 179
# ackermann called with m = 0 n = 180
# ackermann called with m = 0 n = 181
# ackermann called with m = 0 n = 182
# ackermann called with m = 0 n = 183
# ackermann called with m = 0 n = 184
# ackermann called with m = 0 n = 185
# ackermann called with m = 0 n = 186
# ackermann called with m = 0 n = 187
# ackermann called with m = 0 n = 188
# ackermann called with m = 0 n = 189
# ackermann called with m = 0 n = 190
# ackermann called with m = 0 n = 191
# ackermann called with m = 0 n = 192
# ackermann called with m = 0 n = 193
# ackermann called with m = 0 n = 194
# ackermann called with m = 0 n = 195
# ackermann called with m = 0 n = 196
# ackermann called with m = 0 n = 197
# ackermann called with m = 0 n = 198
# ackermann called with m = 0 n = 199
# ackermann called with m = 0 n = 200
# ackermann called with m = 0 n = 201
# ackermann called with m = 0 n = 202
# ackermann called with m = 0 n = 203
# ackermann called with m = 0 n = 204
# ackermann called with m = 0 n = 205
# ackermann called with m = 0 n = 206
# ackermann called with m = 0 n = 207
# ackermann called with m = 0 n = 208
# ackermann called with m = 0 n = 209
# ackermann called with m = 0 n = 210
# ackermann called with m = 0 n = 211
# ackermann called with m = 0 n = 212
# ackermann called with m = 0 n = 213
# ackermann called with m = 0 n = 214
# ackermann called with m = 0 n = 215
# ackermann called with m = 0 n = 216
# ackermann called with m = 0 n = 217
# ackermann called with m = 0 n = 218
# ackermann called with m = 0 n = 219
# ackermann called with m = 0 n = 220
# ackermann called with m = 0 n = 221
# ackermann called with m = 0 n = 222
# ackermann called with m = 0 n = 223
# ackermann called with m = 0 n = 224
# ackermann called with m = 0 n = 225
# ackermann called with m = 0 n = 226
# ackermann called with m = 0 n = 227
# ackermann called with m = 0 n = 228
# ackermann called with m = 0 n = 229
# ackermann called with m = 0 n = 230
# ackermann called with m = 0 n = 231
# ackermann called with m = 0 n = 232
# ackermann called with m = 0 n = 233
# ackermann called with m = 0 n = 234
# ackermann called with m = 0 n = 235
# ackermann called with m = 0 n = 236
# ackermann called with m = 0 n = 237
# ackermann called with m = 0 n = 238
# ackermann called with m = 0 n = 239
# ackermann called with m = 0 n = 240
# ackermann called with m = 0 n = 241
# ackermann called with m = 0 n = 242
# ackermann called with m = 0 n = 243
# ackermann called with m = 0 n = 244
# ackermann called with m = 0 n = 245
# ackermann called with m = 0 n = 246
# ackermann called with m = 0 n = 247
# ackermann called with m = 0 n = 248
# ackermann called with m = 0 n = 249
# ackermann called with m = 0 n = 250
# ackermann called with m = 0 n = 251
# ackermann called with m = 0 n = 252
# ackermann called with m = 0 n = 253
# ackermann called with m = 0 n = 254
# ackermann called with m = 0 n = 255
# ackermann called with m = 0 n = 256
# ackermann called with m = 0 n = 257
# ackermann called with m = 0 n = 258
# ackermann called with m = 0 n = 259
# ackermann called with m = 0 n = 260
# ackermann called with m = 0 n = 261
# ackermann called with m = 0 n = 262
# ackermann called with m = 0 n = 263
# ackermann called with m = 0 n = 264
# ackermann called with m = 0 n = 265
# ackermann called with m = 0 n = 266
# ackermann called with m = 0 n = 267
# ackermann called with m = 0 n = 268
# ackermann called with m = 0 n = 269
# ackermann called with m = 0 n = 270
# ackermann called with m = 0 n = 271
# ackermann called with m = 0 n = 272
# ackermann called with m = 0 n = 273
# ackermann called with m = 0 n = 274
# ackermann called with m = 0 n = 275
# ackermann called with m = 0 n = 276
# ackermann called with m = 0 n = 277
# ackermann called with m = 0 n = 278
# ackermann called with m = 0 n = 279
# ackermann called with m = 0 n = 280
# ackermann called with m = 0 n = 281
# ackermann called with m = 0 n = 282
# ackermann called with m = 0 n = 283
# ackermann called with m = 0 n = 284
# ackermann called with m = 0 n = 285
# ackermann called with m = 0 n = 286
# ackermann called with m = 0 n = 287
# ackermann called with m = 0 n = 288
# ackermann called with m = 0 n = 289
# ackermann called with m = 0 n = 290
# ackermann called with m = 0 n = 291
# ackermann called with m = 0 n = 292
# ackermann called with m = 0 n = 293
# ackermann called with m = 0 n = 294
# ackermann called with m = 0 n = 295
# ackermann called with m = 0 n = 296
# ackermann called with m = 0 n = 297
# ackermann called with m = 0 n = 298
# ackermann called with m = 0 n = 299
# ackermann called with m = 0 n = 300
# ackermann called with m = 0 n = 301
# ackermann called with m = 0 n = 302
# ackermann called with m = 0 n = 303
# ackermann called with m = 0 n = 304
# ackermann called with m = 0 n = 305
# ackermann called with m = 0 n = 306
# ackermann called with m = 0 n = 307
# ackermann called with m = 0 n = 308
# ackermann called with m = 0 n = 309
# ackermann called with m = 0 n = 310
# ackermann called with m = 0 n = 311
# ackermann called with m = 0 n = 312
# ackermann called with m = 0 n = 313
# ackermann called with m = 0 n = 314
# ackermann called with m = 0 n = 315
# ackermann called with m = 0 n = 316
# ackermann called with m = 0 n = 317
# ackermann called with m = 0 n = 318
# ackermann called with m = 0 n = 319
# ackermann called with m = 0 n = 320
# ackermann called with m = 0 n = 321
# ackermann called with m = 0 n = 322
# ackermann called with m = 0 n = 323
# ackermann called with m = 0 n = 324
# ackermann called with m = 0 n = 325
# ackermann called with m = 0 n = 326
# ackermann called with m = 0 n = 327
# ackermann called with m = 0 n = 328
# ackermann called with m = 0 n = 329
# ackermann called with m = 0 n = 330
# ackermann called with m = 0 n = 331
# ackermann called with m = 0 n = 332
# ackermann called with m = 0 n = 333
# ackermann called with m = 0 n = 334
# ackermann called with m = 0 n = 335
# ackermann called with m = 0 n = 336
# ackermann called with m = 0 n = 337
# ackermann called with m = 0 n = 338
# ackermann called with m = 0 n = 339
# ackermann called with m = 0 n = 340
# ackermann called with m = 0 n = 341
# ackermann called with m = 0 n = 342
# ackermann called with m = 0 n = 343
# ackermann called with m = 0 n = 344
# ackermann called with m = 0 n = 345
# ackermann called with m = 0 n = 346
# ackermann called with m = 0 n = 347
# ackermann called with m = 0 n = 348
# ackermann called with m = 0 n = 349
# ackermann called with m = 0 n = 350
# ackermann called with m = 0 n = 351
# ackermann called with m = 0 n = 352
# ackermann called with m = 0 n = 353
# ackermann called with m = 0 n = 354
# ackermann called with m = 0 n = 355
# ackermann called with m = 0 n = 356
# ackermann called with m = 0 n = 357
# ackermann called with m = 0 n = 358
# ackermann called with m = 0 n = 359
# ackermann called with m = 0 n = 360
# ackermann called with m = 0 n = 361
# ackermann called with m = 0 n = 362
# ackermann called with m = 0 n = 363
# ackermann called with m = 0 n = 364
# ackermann called with m = 0 n = 365
# ackermann called with m = 0 n = 366
# ackermann called with m = 0 n = 367
# ackermann called with m = 0 n = 368
# ackermann called with m = 0 n = 369
# ackermann called with m = 0 n = 370
# ackermann called with m = 0 n = 371
# ackermann called with m = 0 n = 372
# ackermann called with m = 0 n = 373
# ackermann called with m = 0 n = 374
# ackermann called with m = 0 n = 375
# ackermann called with m = 0 n = 376
# ackermann called with m = 0 n = 377
# ackermann called with m = 0 n = 378
# ackermann called with m = 0 n = 379
# ackermann called with m = 0 n = 380
# ackermann called with m = 0 n = 381
# ackermann called with m = 0 n = 382
# ackermann called with m = 0 n = 383
# ackermann called with m = 0 n = 384
# ackermann called with m = 0 n = 385
# ackermann called with m = 0 n = 386
# ackermann called with m = 0 n = 387
# ackermann called with m = 0 n = 388
# ackermann called with m = 0 n = 389
# ackermann called with m = 0 n = 390
# ackermann called with m = 0 n = 391
# ackermann called with m = 0 n = 392
# ackermann called with m = 0 n = 393
# ackermann called with m = 0 n = 394
# ackermann called with m = 0 n = 395
# ackermann called with m = 0 n = 396
# ackermann called with m = 0 n = 397
# ackermann called with m = 0 n = 398
# ackermann called with m = 0 n = 399
# ackermann called with m = 0 n = 400
# ackermann called with m = 0 n = 401
# ackermann called with m = 0 n = 402
# ackermann called with m = 0 n = 403
# ackermann called with m = 0 n = 404
# ackermann called with m = 0 n = 405
# ackermann called with m = 0 n = 406
# ackermann called with m = 0 n = 407
# ackermann called with m = 0 n = 408
# ackermann called with m = 0 n = 409
# ackermann called with m = 0 n = 410
# ackermann called with m = 0 n = 411
# ackermann called with m = 0 n = 412
# ackermann called with m = 0 n = 413
# ackermann called with m = 0 n = 414
# ackermann called with m = 0 n = 415
# ackermann called with m = 0 n = 416
# ackermann called with m = 0 n = 417
# ackermann called with m = 0 n = 418
# ackermann called with m = 0 n = 419
# ackermann called with m = 0 n = 420
# ackermann called with m = 0 n = 421
# ackermann called with m = 0 n = 422
# ackermann called with m = 0 n = 423
# ackermann called with m = 0 n = 424
# ackermann called with m = 0 n = 425
# ackermann called with m = 0 n = 426
# ackermann called with m = 0 n = 427
# ackermann called with m = 0 n = 428
# ackermann called with m = 0 n = 429
# ackermann called with m = 0 n = 430
# ackermann called with m = 0 n = 431
# ackermann called with m = 0 n = 432
# ackermann called with m = 0 n = 433
# ackermann called with m = 0 n = 434
# ackermann called with m = 0 n = 435
# ackermann called with m = 0 n = 436
# ackermann called with m = 0 n = 437
# ackermann called with m = 0 n = 438
# ackermann called with m = 0 n = 439
# ackermann called with m = 0 n = 440
# ackermann called with m = 0 n = 441
# ackermann called with m = 0 n = 442
# ackermann called with m = 0 n = 443
# ackermann called with m = 0 n = 444
# ackermann called with m = 0 n = 445
# ackermann called with m = 0 n = 446
# ackermann called with m = 0 n = 447
# ackermann called with m = 0 n = 448
# ackermann called with m = 0 n = 449
# ackermann called with m = 0 n = 450
# ackermann called with m = 0 n = 451
# ackermann called with m = 0 n = 452
# ackermann called with m = 0 n = 453
# ackermann called with m = 0 n = 454
# ackermann called with m = 0 n = 455
# ackermann called with m = 0 n = 456
# ackermann called with m = 0 n = 457
# ackermann called with m = 0 n = 458
# ackermann called with m = 0 n = 459
# ackermann called with m = 0 n = 460
# ackermann called with m = 0 n = 461
# ackermann called with m = 0 n = 462
# ackermann called with m = 0 n = 463
# ackermann called with m = 0 n = 464
# ackermann called with m = 0 n = 465
# ackermann called with m = 0 n = 466
# ackermann called with m = 0 n = 467
# ackermann called with m = 0 n = 468
# ackermann called with m = 0 n = 469
# ackermann called with m = 0 n = 470
# ackermann called with m = 0 n = 471
# ackermann called with m = 0 n = 472
# ackermann called with m = 0 n = 473
# ackermann called with m = 0 n = 474
# ackermann called with m = 0 n = 475
# ackermann called with m = 0 n = 476
# ackermann called with m = 0 n = 477
# ackermann called with m = 0 n = 478
# ackermann called with m = 0 n = 479
# ackermann called with m = 0 n = 480
# ackermann called with m = 0 n = 481
# ackermann called with m = 0 n = 482
# ackermann called with m = 0 n = 483
# ackermann called with m = 0 n = 484
# ackermann called with m = 0 n = 485
# ackermann called with m = 0 n = 486
# ackermann called with m = 0 n = 487
# ackermann called with m = 0 n = 488
# ackermann called with m = 0 n = 489
# ackermann called with m = 0 n = 490
# ackermann called with m = 0 n = 491
# ackermann called with m = 0 n = 492
# ackermann called with m = 0 n = 493
# ackermann called with m = 0 n = 494
# ackermann called with m = 0 n = 495
# ackermann called with m = 0 n = 496
# ackermann called with m = 0 n = 497
# ackermann called with m = 0 n = 498
# ackermann called with m = 0 n = 499
# ackermann called with m = 0 n = 500
# ackermann called with m = 0 n = 501
# ackermann called with m = 0 n = 502
# ackermann called with m = 0 n = 503
# ackermann called with m = 0 n = 504
# ackermann called with m = 0 n = 505
# ackermann called with m = 0 n = 506
# ackermann called with m = 0 n = 507
# ackermann called with m = 0 n = 508
# ackermann called with m = 0 n = 509
# ackermann called with m = 0 n = 510
# ackermann called with m = 0 n = 511
# ackermann called with m = 0 n = 512
# ackermann called with m = 0 n = 513
# ackermann called with m = 0 n = 514
# ackermann called with m = 0 n = 515
# ackermann called with m = 0 n = 516
# ackermann called with m = 0 n = 517
# ackermann called with m = 0 n = 518
# ackermann called with m = 0 n = 519
# ackermann called with m = 0 n = 520
# ackermann called with m = 0 n = 521
# ackermann called with m = 0 n = 522
# ackermann called with m = 0 n = 523
# ackermann called with m = 0 n = 524
# ackermann called with m = 0 n = 525
# ackermann called with m = 0 n = 526
# ackermann called with m = 0 n = 527
# ackermann called with m = 0 n = 528
# ackermann called with m = 0 n = 529
# ackermann called with m = 0 n = 530
# ackermann called with m = 0 n = 531
# ackermann called with m = 0 n = 532
# ackermann called with m = 0 n = 533
# ackermann called with m = 0 n = 534
# ackermann called with m = 0 n = 535
# ackermann called with m = 0 n = 536
# ackermann called with m = 0 n = 537
# ackermann called with m = 0 n = 538
# ackermann called with m = 0 n = 539
# ackermann called with m = 0 n = 540
# ackermann called with m = 0 n = 541
# ackermann called with m = 0 n = 542
# ackermann called with m = 0 n = 543
# ackermann called with m = 0 n = 544
# ackermann called with m = 0 n = 545
# ackermann called with m = 0 n = 546
# ackermann called with m = 0 n = 547
# ackermann called with m = 0 n = 548
# ackermann called with m = 0 n = 549
# ackermann called with m = 0 n = 550
# ackermann called with m = 0 n = 551
# ackermann called with m = 0 n = 552
# ackermann called with m = 0 n = 553
# ackermann called with m = 0 n = 554
# ackermann called with m = 0 n = 555
# ackermann called with m = 0 n = 556
# ackermann called with m = 0 n = 557
# ackermann called with m = 0 n = 558
# ackermann called with m = 0 n = 559
# ackermann called with m = 0 n = 560
# ackermann called with m = 0 n = 561
# ackermann called with m = 0 n = 562
# ackermann called with m = 0 n = 563
# ackermann called with m = 0 n = 564
# ackermann called with m = 0 n = 565
# ackermann called with m = 0 n = 566
# ackermann called with m = 0 n = 567
# ackermann called with m = 0 n = 568
# ackermann called with m = 0 n = 569
# ackermann called with m = 0 n = 570
# ackermann called with m = 0 n = 571
# ackermann called with m = 0 n = 572
# ackermann called with m = 0 n = 573
# ackermann called with m = 0 n = 574
# ackermann called with m = 0 n = 575
# ackermann called with m = 0 n = 576
# ackermann called with m = 0 n = 577
# ackermann called with m = 0 n = 578
# ackermann called with m = 0 n = 579
# ackermann called with m = 0 n = 580
# ackermann called with m = 0 n = 581
# ackermann called with m = 0 n = 582
# ackermann called with m = 0 n = 583
# ackermann called with m = 0 n = 584
# ackermann called with m = 0 n = 585
# ackermann called with m = 0 n = 586
# ackermann called with m = 0 n = 587
# ackermann called with m = 0 n = 588
# ackermann called with m = 0 n = 589
# ackermann called with m = 0 n = 590
# ackermann called with m = 0 n = 591
# ackermann called with m = 0 n = 592
# ackermann called with m = 0 n = 593
# ackermann called with m = 0 n = 594
# ackermann called with m = 0 n = 595
# ackermann called with m = 0 n = 596
# ackermann called with m = 0 n = 597
# ackermann called with m = 0 n = 598
# ackermann called with m = 0 n = 599
# ackermann called with m = 0 n = 600
# ackermann called with m = 0 n = 601
# ackermann called with m = 0 n = 602
# ackermann called with m = 0 n = 603
# ackermann called with m = 0 n = 604
# ackermann called with m = 0 n = 605
# ackermann called with m = 0 n = 606
# ackermann called with m = 0 n = 607
# ackermann called with m = 0 n = 608
# ackermann called with m = 0 n = 609
# ackermann called with m = 0 n = 610
# ackermann called with m = 0 n = 611
# ackermann called with m = 0 n = 612
# ackermann called with m = 0 n = 613
# ackermann called with m = 0 n = 614
# ackermann called with m = 0 n = 615
# ackermann called with m = 0 n = 616
# ackermann called with m = 0 n = 617
# ackermann called with m = 0 n = 618
# ackermann called with m = 0 n = 619
# ackermann called with m = 0 n = 620
# ackermann called with m = 0 n = 621
# ackermann called with m = 0 n = 622
# ackermann called with m = 0 n = 623
# ackermann called with m = 0 n = 624
# ackermann called with m = 0 n = 625
# ackermann called with m = 0 n = 626
# ackermann called with m = 0 n = 627
# ackermann called with m = 0 n = 628
# ackermann called with m = 0 n = 629
# ackermann called with m = 0 n = 630
# ackermann called with m = 0 n = 631
# ackermann called with m = 0 n = 632
# ackermann called with m = 0 n = 633
# ackermann called with m = 0 n = 634
# ackermann called with m = 0 n = 635
# ackermann called with m = 0 n = 636
# ackermann called with m = 0 n = 637
# ackermann called with m = 0 n = 638
# ackermann called with m = 0 n = 639
# ackermann called with m = 0 n = 640
# ackermann called with m = 0 n = 641
# ackermann called with m = 0 n = 642
# ackermann called with m = 0 n = 643
# ackermann called with m = 0 n = 644
# ackermann called with m = 0 n = 645
# ackermann called with m = 0 n = 646
# ackermann called with m = 0 n = 647
# ackermann called with m = 0 n = 648
# ackermann called with m = 0 n = 649
# ackermann called with m = 0 n = 650
# ackermann called with m = 0 n = 651
# ackermann called with m = 0 n = 652
# ackermann called with m = 0 n = 653
# ackermann called with m = 0 n = 654
# ackermann called with m = 0 n = 655
# ackermann called with m = 0 n = 656
# ackermann called with m = 0 n = 657
# ackermann called with m = 0 n = 658
# ackermann called with m = 0 n = 659
# ackermann called with m = 0 n = 660
# ackermann called with m = 0 n = 661
# ackermann called with m = 0 n = 662
# ackermann called with m = 0 n = 663
# ackermann called with m = 0 n = 664
# ackermann called with m = 0 n = 665
# ackermann called with m = 0 n = 666
# ackermann called with m = 0 n = 667
# ackermann called with m = 0 n = 668
# ackermann called with m = 0 n = 669
# ackermann called with m = 0 n = 670
# ackermann called with m = 0 n = 671
# ackermann called with m = 0 n = 672
# ackermann called with m = 0 n = 673
# ackermann called with m = 0 n = 674
# ackermann called with m = 0 n = 675
# ackermann called with m = 0 n = 676
# ackermann called with m = 0 n = 677
# ackermann called with m = 0 n = 678
# ackermann called with m = 0 n = 679
# ackermann called with m = 0 n = 680
# ackermann called with m = 0 n = 681
# ackermann called with m = 0 n = 682
# ackermann called with m = 0 n = 683
# ackermann called with m = 0 n = 684
# ackermann called with m = 0 n = 685
# ackermann called with m = 0 n = 686
# ackermann called with m = 0 n = 687
# ackermann called with m = 0 n = 688
# ackermann called with m = 0 n = 689
# ackermann called with m = 0 n = 690
# ackermann called with m = 0 n = 691
# ackermann called with m = 0 n = 692
# ackermann called with m = 0 n = 693
# ackermann called with m = 0 n = 694
# ackermann called with m = 0 n = 695
# ackermann called with m = 0 n = 696
# ...
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 739
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=738)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 738
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=737)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 737
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=736)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 736
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=735)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 735
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=734)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 734
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=733)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 733
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=732)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 732
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=731)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 731
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=730)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 730
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=729)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 729
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=728)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 728
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=727)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 727
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=726)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 726
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=725)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 725
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=724)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 724
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=723)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 723
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=722)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 722
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=721)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 721
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=720)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 720
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=719)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 719
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=718)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 718
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=717)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 717
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=716)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 716
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=715)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 715
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=714)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 714
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=713)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 713
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=712)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 712
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=711)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 711
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=710)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 710
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=709)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 709
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=708)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 708
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=707)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 707
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=706)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 706
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=705)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 705
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=704)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 704
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=703)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 703
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=702)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 702
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=701)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 701
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=700)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 700
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=699)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 699
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=698)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 698
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=697)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 697
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=696)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 696
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=695)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 695
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=694)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 694
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=693)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 693
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=692)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 692
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=691)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 691
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=690)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 690
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=689)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 689
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=688)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 688
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=687)
#       6         return ackermann(m-1, 1)
#       7     else:
# ----> 8         return ackermann(m-1, ackermann(m, n-1))
#         global ackermann = <function ackermann at 0x7d105cd38400>
#         m = 1
#         n = 687
#       9
#
# /tmp/ipython-input-3695600379.py in ackermann(m=1, n=686)
#       1 def ackermann(m, n):
# ----> 2     print("ackermann called with m =", m, "n =", n)  # <-- print statement added
#         global print = undefined
#         m = 1
#         n = 686
#       3     if m == 0:
#       4         return n + 1
#       5     elif n == 0:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in write(self=<ipykernel.iostream.OutStream object>, string='ackermann called with m =')
#     548         else:
#     549
# --> 550             is_child = not self._is_master_process()
#         is_child = undefined
#         self._is_master_process = <bound method OutStream._is_master_process of <ipykernel.iostream.OutStream object at 0x7d106e56fc70>>
#     551             # only touch the buffer in the IO thread to avoid races
#     552             with self._buffer_lock:
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/iostream.py in _is_master_process(self=<ipykernel.iostream.OutStream object>)
#     436
#     437     def _is_master_process(self):
# --> 438         return os.getpid() == self._master_pid
#         global os.getpid = <built-in function getpid>
#         self._master_pid = 316
#     439
#     440     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %% [markdown]
# To see why, add a print statement to the beginning of the function to display the values of the parameters, and then run the examples again.

# %% [markdown]
# ### Exercise
#
# A number, $a$, is a power of $b$ if it is divisible by $b$ and $a/b$ is
# a power of $b$. Write a function called `is_power` that takes parameters
# `a` and `b` and returns `True` if `a` is a power of `b`. Note: you will
# have to think about the base case.

# %%
# Solution goes here

# %% [markdown]
# You can use these examples to test your function.

# %%
is_power(65536, 2)   # should be True

# %%
is_power(27, 3)  # should be True

# %%
is_power(24, 2)  # should be False

# %%
is_power(1, 17)   # should be True

# %% [markdown]
# ### Exercise
#
# The greatest common divisor (GCD) of $a$ and $b$ is the largest number
# that divides both of them with no remainder.
#
# One way to find the GCD of two numbers is based on the observation that
# if $r$ is the remainder when $a$ is divided by $b$, then $gcd(a,
# b) = gcd(b, r)$. As a base case, we can use $gcd(a, 0) = a$.
#
# Write a function called `gcd` that takes parameters `a` and `b` and
# returns their greatest common divisor.

# %%
# Solution goes here

# %% [markdown]
# You can use these examples to test your function.

# %%
gcd(12, 8)    # should be 4

# %%
gcd(13, 17)   # should be 1

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
